# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.utils import compute_class_weight
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import xgboost as xgb
from sklearn.feature_selection import SelectKBest, f_classif

# %%
transpot=pd.read_csv('../../data/PDBP/Transcriptomics/Processed_PDBP_transpot_handle.csv',index_col=0)

# %%
transpot
# Out:
#                                PATNO     PATNO Visit Visit  label  \
# PD-PDMZ724XCN-SVM18T1  PD-PDMZ724XCN  PDMZ724XCN_V05   V05    2.0
# PD-PDCT406CN9-SVM12T1  PD-PDCT406CN9  PDCT406CN9_V04   V04    2.0
# PD-PDDE532JGE-SVM12T1  PD-PDDE532JGE  PDDE532JGE_V04   V04    2.0
# PD-PDMX081PLW-SVM12T1  PD-PDMX081PLW  PDMX081PLW_V04   V04    2.0
# PD-PDLK184WGE-BLM0T1   PD-PDLK184WGE   PDLK184WGE_BL    BL    2.0
# ...                              ...             ...   ...    ...
# PD-PDGB282NN9-SVM24T1  PD-PDGB282NN9  PDGB282NN9_V06   V06    0.0
# PD-PDYZ819YLQ-BLM0T1   PD-PDYZ819YLQ   PDYZ819YLQ_BL    BL    2.0
# PD-PDGU754YXE-SVM18T1  PD-PDGU754YXE  PDGU754YXE_V05   V05    5.0
# PD-PDCG654NZL-BLM0T1   PD-PDCG654NZL   PDCG654NZL_BL    BL    3.0
# PD-PDVX986CEU-SVM6T1   PD-PDVX986CEU  PDVX986CEU_V02   V02    0.0
#
#                        ENSG00000242268.2  ENSG00000259041.1  \
# PD-PDMZ724XCN-SVM18T1                  0                  0
# ...

# %%
transpot['label']=transpot['label'].astype(int)

# %%
transpot
# Out:
#                                PATNO     PATNO Visit Visit  label  \
# PD-PDMZ724XCN-SVM18T1  PD-PDMZ724XCN  PDMZ724XCN_V05   V05      2
# PD-PDCT406CN9-SVM12T1  PD-PDCT406CN9  PDCT406CN9_V04   V04      2
# PD-PDDE532JGE-SVM12T1  PD-PDDE532JGE  PDDE532JGE_V04   V04      2
# PD-PDMX081PLW-SVM12T1  PD-PDMX081PLW  PDMX081PLW_V04   V04      2
# PD-PDLK184WGE-BLM0T1   PD-PDLK184WGE   PDLK184WGE_BL    BL      2
# ...                              ...             ...   ...    ...
# PD-PDGB282NN9-SVM24T1  PD-PDGB282NN9  PDGB282NN9_V06   V06      0
# PD-PDYZ819YLQ-BLM0T1   PD-PDYZ819YLQ   PDYZ819YLQ_BL    BL      2
# PD-PDGU754YXE-SVM18T1  PD-PDGU754YXE  PDGU754YXE_V05   V05      5
# PD-PDCG654NZL-BLM0T1   PD-PDCG654NZL   PDCG654NZL_BL    BL      3
# PD-PDVX986CEU-SVM6T1   PD-PDVX986CEU  PDVX986CEU_V02   V02      0
#
#                        ENSG00000242268.2  ENSG00000259041.1  \
# PD-PDMZ724XCN-SVM18T1                  0                  0
# ...

# %%
transpot['label'].value_counts()
# Out:
# 2    1968
# 0    1054
# 3     234
# 1     208
# 4      93
# 5      50
# Name: label, dtype: int64

# %% [markdown]
# ## 独立验证集测试集

# %%
X_train=transpot.drop(['PATNO','Visit'],axis=1)

# %%
X_train
# Out:
#                           PATNO Visit  label  ENSG00000242268.2  \
# PD-PDMZ724XCN-SVM18T1  PDMZ724XCN_V05      2                  0
# PD-PDCT406CN9-SVM12T1  PDCT406CN9_V04      2                  1
# PD-PDDE532JGE-SVM12T1  PDDE532JGE_V04      2                  1
# PD-PDMX081PLW-SVM12T1  PDMX081PLW_V04      2                  2
# PD-PDLK184WGE-BLM0T1    PDLK184WGE_BL      2                  0
# ...                               ...    ...                ...
# PD-PDGB282NN9-SVM24T1  PDGB282NN9_V06      0                  0
# PD-PDYZ819YLQ-BLM0T1    PDYZ819YLQ_BL      2                  0
# PD-PDGU754YXE-SVM18T1  PDGU754YXE_V05      5                  0
# PD-PDCG654NZL-BLM0T1    PDCG654NZL_BL      3                  0
# PD-PDVX986CEU-SVM6T1   PDVX986CEU_V02      0                  0
#
#                        ENSG00000259041.1  ENSG00000207641.1  \
# PD-PDMZ724XCN-SVM18T1                  0                  0
# PD-PDCT406CN9-SVM12T1                  1                  0
# ...

# %%
X_train.index=X_train['PATNO Visit']

# %%
X_train=X_train.drop(['PATNO Visit'],axis=1)

# %%
X_train
# Out:
#                 label  ENSG00000242268.2  ENSG00000259041.1  \
# PATNO Visit
# PDMZ724XCN_V05      2                  0                  0
# PDCT406CN9_V04      2                  1                  1
# PDDE532JGE_V04      2                  1                  0
# PDMX081PLW_V04      2                  2                  0
# PDLK184WGE_BL       2                  0                  0
# ...               ...                ...                ...
# PDGB282NN9_V06      0                  0                  2
# PDYZ819YLQ_BL       2                  0                  0
# PDGU754YXE_V05      5                  0                  1
# PDCG654NZL_BL       3                  0                  0
# PDVX986CEU_V02      0                  0                  0
#
#                 ENSG00000207641.1  ENSG00000270112.3  ENSG00000280143.1  \
# PATNO Visit
# PDMZ724XCN_V05                  0                  0                  9
# ...

# %%
X_val=pd.read_csv('../../processed_data/PDBP/overlap/X_val_transpot.csv')
X_test=pd.read_csv('../../processed_data/PDBP/overlap/X_test_transpot.csv')

# %%
X_val
# Out:
#         PATNO Visit_2     PATNO Visit  ENSG00000242268.2  ENSG00000259041.1  \
# 0     PDUW145KTG_BL_1   PDUW145KTG_BL                  1                  0
# 1     PDMW095JLA_BL_2   PDMW095JLA_BL                  0                  0
# 2    PDGG982KFF_V04_1  PDGG982KFF_V04                  0                  0
# 3     PDWE305WN6_BL_1   PDWE305WN6_BL                  0                  0
# 4      PDBM325HN9_V04  PDBM325HN9_V04                  0                  0
# ..                ...             ...                ...                ...
# 101   PDDH347KKC_BL_3   PDDH347KKC_BL                  0                  0
# 102  PDGT740ZXE_V04_1  PDGT740ZXE_V04                  0                  0
# 103  PDTJ033DDH_V04_1  PDTJ033DDH_V04                  4                  2
# 104     PDZF975VVM_BL   PDZF975VVM_BL                  2                  0
# 105     PDBH812DN5_BL   PDBH812DN5_BL                  0                  2
#
# ...

# %%
X_val_list=X_val['PATNO Visit'].values.tolist()
X_test_list=X_test['PATNO Visit'].values.tolist()

# %%
X_train_new=X_train[~X_train.index.isin(X_test_list) & ~X_train.index.isin(X_val_list)]

# %%
X_train_new
# Out:
#                 label  ENSG00000242268.2  ENSG00000259041.1  \
# PATNO Visit
# PDMZ724XCN_V05      2                  0                  0
# PDDE532JGE_V04      2                  1                  0
# PDMX081PLW_V04      2                  2                  0
# PDLK184WGE_BL       2                  0                  0
# PDXW222GG2_BL       2                  0                  0
# ...               ...                ...                ...
# PDGB282NN9_V06      0                  0                  2
# PDYZ819YLQ_BL       2                  0                  0
# PDGU754YXE_V05      5                  0                  1
# PDCG654NZL_BL       3                  0                  0
# PDVX986CEU_V02      0                  0                  0
#
#                 ENSG00000207641.1  ENSG00000270112.3  ENSG00000280143.1  \
# PATNO Visit
# PDMZ724XCN_V05                  0                  0                  9
# ...

# %%
X_train=X_train_new.drop(['label'],axis=1)
y_train=X_train_new['label']

# %%
X_train.to_csv('../../processed_data/PDBP/Transcriptomics/X_train.csv')
y_train.to_csv('../../processed_data/PDBP/Transcriptomics/y_train.csv')
# Out:
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。请查看单元格中的代码，以确定故障的可能原因。有关详细信息，请单击 <a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>。有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。

# %% [markdown]
# ## 不独立

# %%
X = transpot.drop(['PATNO','PATNO Visit','Visit','label'],axis=1).values.astype(float)
y = transpot["label"].astype(int).values

# %%
X.shape
# Out:
# (3607, 57648)

# %%
y.shape
# Out:
# (3607,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)
y_train = pd.DataFrame(y_train)
y_test = pd.DataFrame(y_test)

# %%
X_train.to_csv('../../processed_data/PDBP/Transcriptomics/X_train.csv')
X_test.to_csv('../../processed_data/PDBP/Transcriptomics/X_test.csv')
y_train.to_csv('../../processed_data/PDBP/Transcriptomics/y_train.csv')
y_test.to_csv('../../processed_data/PDBP/Transcriptomics/y_test.csv')

# %%
transpot.drop(['PATNO','Visit'],axis=1)
# Out:
#                           PATNO Visit  label  ENSG00000242268.2  \
# PD-PDMZ724XCN-SVM18T1  PDMZ724XCN_V05      2                  0
# PD-PDCT406CN9-SVM12T1  PDCT406CN9_V04      2                  1
# PD-PDDE532JGE-SVM12T1  PDDE532JGE_V04      2                  1
# PD-PDMX081PLW-SVM12T1  PDMX081PLW_V04      2                  2
# PD-PDLK184WGE-BLM0T1    PDLK184WGE_BL      2                  0
# ...                               ...    ...                ...
# PD-PDGB282NN9-SVM24T1  PDGB282NN9_V06      0                  0
# PD-PDYZ819YLQ-BLM0T1    PDYZ819YLQ_BL      2                  0
# PD-PDGU754YXE-SVM18T1  PDGU754YXE_V05      5                  0
# PD-PDCG654NZL-BLM0T1    PDCG654NZL_BL      3                  0
# PD-PDVX986CEU-SVM6T1   PDVX986CEU_V02      0                  0
#
#                        ENSG00000259041.1  ENSG00000207641.1  \
# PD-PDMZ724XCN-SVM18T1                  0                  0
# PD-PDCT406CN9-SVM12T1                  1                  0
# ...

# %%
transpot.drop(['PATNO','Visit'],axis=1).to_csv('../../processed_data/PDBP/Transcriptomics/transpot_all.csv')
